# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("BlackFriday.csv")

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.drop("Product_Category_2",axis=1,inplace=True)

# %%
df.drop("Product_Category_3",axis=1,inplace=True)

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df["Stay_In_Current_City_Years"].nunique()
# Out:
# 5

# %%
sn.countplot(data=df,x="Stay_In_Current_City_Years")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df["Stay_In_Current_City_Years"].value_counts()
# Out:
# Stay_In_Current_City_Years
# 1     189192
# 2      99459
# 3      93312
# 4+     82889
# 0      72725
# Name: count, dtype: int64

# %%
df["Stay_In_Current_City_Years"].value_counts().plot(kind="pie",autopct="%0.2f")
# Out:
# <Axes: ylabel='count'>

# %%
sn.countplot(data=df,x="Stay_In_Current_City_Years",hue="Gender")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby(["Gender","Stay_In_Current_City_Years"]).size()
# Out:
# Gender  Stay_In_Current_City_Years
# F       0                              16564
#         1                              49995
#         2                              23718
#         3                              23892
#         4+                             18028
# M       0                              56161
#         1                             139197
#         2                              75741
#         3                              69420
#         4+                             64861
# dtype: int64

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
sn.countplot(data=df,x="Marital_Status",hue="Stay_In_Current_City_Years")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
df.groupby(["Stay_In_Current_City_Years","Marital_Status"]).size()
# Out:
# Stay_In_Current_City_Years  Marital_Status
# 0                           0                  43916
#                             1                  28809
# 1                           0                 108337
#                             1                  80855
# 2                           0                  59419
#                             1                  40040
# 3                           0                  56471
#                             1                  36841
# 4+                          0                  49674
#                             1                  33215
# dtype: int64

# %%
sn.countplot(data=df,x="Stay_In_Current_City_Years",hue="City_Category")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby(["Stay_In_Current_City_Years","City_Category"]).size()
# Out:
# Stay_In_Current_City_Years  City_Category
# 0                           A                23700
#                             B                28143
#                             C                20882
# 1                           A                48160
#                             B                81622
#                             C                59410
# 2                           A                26548
#                             B                40800
#                             C                32111
# 3                           A                24389
#                             B                41964
#                             C                26959
# 4+                          A                21841
#                             B                33964
#                             C                27084
# dtype: int64

# %%
sn.countplot(data=df,x="Stay_In_Current_City_Years",hue="Age")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby(["Age","Stay_In_Current_City_Years"]).size()
# Out:
# Age    Stay_In_Current_City_Years
# 0-17   0                              2170
#        1                              4805
#        2                              3415
#        3                              2697
#        4+                             1620
# 18-25  0                             16283
#        1                             31531
#        2                             18868
#        3                             15122
#        4+                            15830
# 26-35  0                             26969
#        1                             75745
#        2                             38967
#        3                             38752
#        4+                            34257
# 36-45  0                             13699
#        1                             36151
#        2                             20537
#        3                             22484
#        4+                            14628
# 46-50  0                              6537
# ...

# %%
sn.countplot(data=df,x="City_Category",hue="Age")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby(["Age","City_Category"]).size()
# Out:
# Age    City_Category
# 0-17   A                 2497
#        B                 5288
#        C                 6922
# 18-25  A                27025
#        B                42470
#        C                28139
# 26-35  A                72048
#        B                89767
#        C                52875
# 36-45  A                26142
#        B                46605
#        C                34752
# 46-50  A                 7467
#        B                19900
#        C                17159
# 51-55  A                 5969
#        B                17435
#        C                14214
# 55+    A                 3490
#        B                 5028
#        C                12385
# dtype: int64

# %%
df.groupby('Stay_In_Current_City_Years').sum()['Purchase'].plot(kind = 'bar')
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
sn.countplot(data=df,x="Occupation")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df["Occupation"].nunique()
# Out:
# 21

# %%
df.groupby("Occupation").size().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
sn.countplot(data=df,x="Occupation",hue="Marital_Status")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 sn.countplot(data=df,x="Occupation",hue="Marital_Status")
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
# ...

# %%
df.groupby(["Marital_Status","Occupation"]).size()
# Out:
# Marital_Status  Occupation
# 0               0             39664
#                 1             24065
#                 2             13906
#                 3             10202
#                 4             51723
#                 5              7473
#                 6             10983
#                 7             32693
#                 8               672
#                 9              3001
#                 10            11892
#                 11             6997
#                 12            16208
#                 13             3553
#                 14            15772
#                 15             6483
#                 16            13042
#                 17            22243
#                 18             3549
#                 19             6853
#                 20            16843
# 1               0             28456
#                 1             21906
#                 2             11939
#                 3              7164
# ...

# %%
sn.countplot(data=df,x="Occupation",hue="Gender")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
df.groupby(["Gender","Occupation"]).size()
# Out:
# Gender  Occupation
# F       0             17658
#         1             17431
#         2              8402
#         3              7767
#         4             17340
#         5              2160
#         6              7971
#         7              9707
#         8               357
#         9              5707
#         10             3912
#         11             1454
#         12             3387
#         13             1445
#         14             6621
#         15             2302
#         16             3996
#         17             3742
#         18              216
#         19             1974
#         20             8648
# M       0             50462
#         1             28540
#         2             17443
#         3              9599
#         4             53522
#         5              9825
#         6             11851
#         7             48099
#         8              1167
#         9               446
#         10             8711
# ...

# %%
df.groupby("Occupation").nunique()["Product_ID"].plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation").nunique()["Product_ID"].sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df[]
# Out:
#   Cell In[42], line 1
#     df[]
#        ^
# SyntaxError: invalid syntax

# %%
df["Product_Category_1"].nunique()
# Out:
# 18

# %%
df.groupby("Product_Category_1").size().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
sn.countplot(data=df,x="Product_Category_1",hue="Gender")
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
df.groupby(["Gender","Product_Category_1"]).size()
# Out:
# Gender  Product_Category_1
# F       1                      24401
#         2                       5573
#         3                       5874
#         4                       3572
#         5                      41199
#         6                       4475
#         7                        928
#         8                      32947
#         9                         70
#         10                      1138
#         11                      4659
#         12                      1497
#         13                      1428
#         14                       613
#         15                      1023
#         16                      2363
#         17                        61
#         18                       376
# M       1                     113952
#         2                      17926
#         3                      13975
#         4                       7995
#         5                     107393
#         6                      15689
# ...

# %%
sn.countplot(data=df,hue="Product_Category_1",x="Marital_Status")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 sn.countplot(data=df,hue="Product_Category_1",x="Marital_Status")
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
# ...

# %%
df.groupby(["Marital_Status","Product_Category_1"]).size()
# Out:
# Marital_Status  Product_Category_1
# 0               1                     83230
#                 2                     13946
#                 3                     12158
#                 4                      7072
#                 5                     88411
#                 6                     11986
#                 7                      2004
#                 8                     64484
#                 9                       242
#                 10                     2734
#                 11                    14479
#                 12                     1999
#                 13                     3107
#                 14                      835
#                 15                     3577
#                 16                     5640
#                 17                      291
#                 18                     1622
# 1               1                     55123
#                 2                      9553
# ...

# %% [markdown]
# # Combining Gender and Marital Status

# %%
l=[]
for i in range(len(df)):
    l.append(df['Gender'][i] +"_"+ str(df['Marital_Status'][i]))
df["MaritalGneder"]=l

# %%
sn.countplot(data=df,x="MaritalGneder")
# Out:
# <Axes: xlabel='MaritalGneder', ylabel='count'>

# %%
sn.countplot(data=df,x="Marital_Status",hue="Gender")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sn.countplot(data=df,x="Age",hue="MaritalGneder")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
l1=[]
for i in range(len(df)):
    l1.append(df["City_Category"][i]+"_"+str(df["Marital_Status"][i]))
df["MaritalCity"]=l1

# %%
sn.countplot(data=df,x="MaritalCity")
# Out:
# <Axes: xlabel='MaritalCity', ylabel='count'>

# %%
df.groupby("MaritalCity").size()
# Out:
# MaritalCity
# A_0     89388
# A_1     55250
# B_0    134213
# B_1     92280
# C_0     94216
# C_1     72230
# dtype: int64

# %%
sn.countplot(x="Product_Category_1",data=df,hue="MaritalGneder")
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sn.countplot(data=df,x='Stay_In_Current_City_Years',hue="MaritalCity")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sn.countplot(data=df,x='Stay_In_Current_City_Years',hue="MaritalGneder")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sn.countplot(data=df,x="MaritalCity",hue="MaritalGneder")
# Out:
# <Axes: xlabel='MaritalCity', ylabel='count'>

# %%
df.groupby(["MaritalGneder","MaritalCity"]).size()
# Out:
# MaritalGneder  MaritalCity
# F_0            A_0             21301
#                B_0             33897
#                C_0             21776
# F_1            A_1             13506
#                B_1             22597
#                C_1             19120
# M_0            A_0             68087
#                B_0            100316
#                C_0             72440
# M_1            A_1             41744
#                B_1             69683
#                C_1             53110
# dtype: int64

# %%
l2=[]
for i in range(len(df))
# Out:
#   Cell In[66], line 2
#     for i in range(len(df))
#                            ^
# SyntaxError: expected ':'
