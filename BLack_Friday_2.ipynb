# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df=pd.read_csv("BlackFriday.csv")

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.drop("Product_Category_2",axis=1,inplace=True)

# %%
df.drop("Product_Category_3",axis=1,inplace=True)

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %%
df.groupby("Age").size().plot(kind="bar",title="Age distribution",figsize=(10,6))
# Out:
# <Axes: title={'center': 'Age distribution'}, xlabel='Age'>

# %%
plt.title("Age distribution with gender")
sn.countplot(data=df,x="Age",hue="Gender")
plt.show()

# %%
plt.title("Gender distribution with Age")
sn.countplot(data=df,x="Gender",hue="Age")
plt.show()

# %%
plt.title("Age distribution with Marital Status")
sn.countplot(data=df,x="Age",hue="Marital_Status")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 2
#       1 plt.title("Age distribution with Marital Status")
# ----> 2 sn.countplot(data=df,x="Age",hue="Marital_Status")
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
# ...

# %%
plt.title("Gender distribution with Marital Status")
sn.countplot(data=df,x="Gender",hue="Marital_Status")


plt.show()

# %%
plt.title("Marital Status distribution with gender")
sn.countplot(data=df,x="Marital_Status",hue="Gender")


plt.show()

# %%
df["City_Category"].unique()

# %%
sn.countplot(data=df,x="City_Category")

# %%
plt.title("City_Category with Age")
sn.countplot(data=df,x="City_Category",hue="Age")


plt.show()

# %%
plt.title("City_Category with gender")
sn.countplot(data=df,x="City_Category",hue="Gender")


plt.show()

# %%
df.groupby("Gender").count()["City_Category"]

# %%
gender_counts = df.groupby(['Gender',"City_Category"]).size()

print(gender_counts)

# %%
product_purchases=df.groupby(["Product_Category_1","Gender"]).size()
print(product_purchases)

# %% [raw]
# purchasesygender=df.groupby("Gender").sum()["Purchase"]
# print(purchasesygender)

# %%
marital=df.groupby(["City_Category","Marital_Status"]).size()
print(marital)

# %% [raw]
# marital_sum=df.groupby(["City_Category"]).sum()["Marital_Status"]
# print(marital_sum)

# %%
print(df.groupby("Marital_Status").size())
# Out:
# Marital_Status
# 0    317817
# 1    219760
# dtype: int64

# %%
sn.countplot(data=df,x="City_Category",hue="Age")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby(["City_Category","Age"]).size()
# Out:
# City_Category  Age
# A              0-17      2497
#                18-25    27025
#                26-35    72048
#                36-45    26142
#                46-50     7467
#                51-55     5969
#                55+       3490
# B              0-17      5288
#                18-25    42470
#                26-35    89767
#                36-45    46605
#                46-50    19900
#                51-55    17435
#                55+       5028
# C              0-17      6922
#                18-25    28139
#                26-35    52875
#                36-45    34752
#                46-50    17159
#                51-55    14214
#                55+      12385
# dtype: int64

# %%
sn.countplot(data=df,x="Age",hue="City_Category")
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
df.groupby(["Age","City_Category"]).size()
# Out:
# Age    City_Category
# 0-17   A                 2497
#        B                 5288
#        C                 6922
# 18-25  A                27025
#        B                42470
#        C                28139
# 26-35  A                72048
#        B                89767
#        C                52875
# 36-45  A                26142
#        B                46605
#        C                34752
# 46-50  A                 7467
#        B                19900
#        C                17159
# 51-55  A                 5969
#        B                17435
#        C                14214
# 55+    A                 3490
#        B                 5028
#        C                12385
# dtype: int64

# %%
sn.countplot(data=df,hue="City_Category",x="Marital_Status")
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
df["City_Category"].value_counts().plot(kind="pie",autopct="%0.2f")
# Out:
# <Axes: ylabel='count'>

# %%
sn.countplot(data=df,x="City_Category",hue="Gender")
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby("City_Category").sum()["Purchase"].plot(kind="pie",autopct="%0.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby("City_Category").mean()["Purchase"].plot(kind="pie",autopct="%")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
#     878     res = extract_result(res)
#
# ...
